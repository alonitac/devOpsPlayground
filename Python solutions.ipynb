# %% [markdown]
# ## Is unique string
# Write a program that given a string, determines whether all characters are unique:

# %%
my_str = 'bacdfgjhlukje'

# %% [markdown]
# ### The natural solution

# %%
is_unique = True

for i in range(len(my_str)):
    for j in range(i + 1, len(my_str)):
        if my_str[i] == my_str[j]:
            is_unique = False

if is_unique:
    print("is unique")
else:
    print("is'nt unique")
    
# alternative
# print("is unique" if is_unique else "is'nt unique")
# Out:
# is'nt unique

# %% [markdown]
# ### The optimal solution

# %%
visited_char = {}

my_str = 'bacdfgjhlukje'

for c in my_str:
    if c in visited_char:
        print("isn't unique")
        break
        
    visited_char[c] = True
# Out:
# isn't unique

# %% [markdown]
# ### The elegant solution

# %%
if len(set(my_str)) == len(my_str):
    print('is unique')
else:
    print("isn't unique")
# Out:
# is unique

# %% [markdown]
# ## Sum of elements
# Write a program that given a list of numbers, calculates the sum of all elements :

# %%
my_list = [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# ### The elegant solution

# %%
sum(my_list)
# Out:
# 36

# %% [markdown]
# ### The natural solution

# %%
s = 0
for num in my_list:
    s = s + num
print(s)
# Out:
# 36

# %% [markdown]
# ### The recursive solution

# %%
def sum_of_all(lst):
    if len(lst) == 0:
        return 0
    return sum_of_all(lst[1:]) + lst[0]


sum_of_all(my_list)
# Out:
# 36

# %% [markdown]
# ## Zig Zag
# A sequence of integers is called a zigzag sequence if each of its elements is either strictly less than both
# neighbors or strictly greater than both neighbors. For example, the sequence 4 2 3 1 5 3 is a zigzag,
#  but 7 3 5 5 2 and 3 8 6 4 5 aren't.
#
# For a given array of integers return the length of its longest contiguous sub-array that is a zigzag sequence.
#
# Example
# For a = [9, 8, 8, 5, 3, 5, 3, 2, 8, 6], the output should be
# zigzag(a) = 4.
#
# The longest zigzag sub-arrays are [5, 3, 5, 3] and [3, 2, 8, 6] and they both have length 4.

# %%
a = [9, 8, 8, 5, 3, 5, 3, 2, 8, 6]

# %%
max_zz = 0

for i in range(len(a) - 1):

    zz_count = 1  
    zz_state = 0
    
    for j in range(i, len(a) - 1): 
        
        if zz_state != -1 and a[j] < a[j + 1]:
            zz_state = -1
            zz_count += 1
            
        elif zz_state != 1 and a[j] > a[j + 1]:
            zz_state = 1
            zz_count += 1
            
        else:
            break  # breaking from the internal loop
    
    max_zz = max(zz_count, max_zz)

print(max_zz)
# Out:
# 4

# %% [markdown]
# ## Words Concat
# Given a list of workds, and a seperator "sep", write a program that concatenates the words, using "sep" as a seperator.
#
#
# Use must use the string function **join**

# %%
words = ['take', 'me', 'home']
sep = ' '

# %%
words = ['A', 'picture', 'is', 'worth', '1000', 'words']
sep = '-'

# %%
Your Program
# Out:
# 'A-picture-is-worth-1000-words'

# %% [markdown]
# #### Solution

# %%
sep.join(words)
# Out:
# 'take me home'

# %% [markdown]
# ## Valid parentheses (Adavanced)
# Given a string containing \[,\{,\(,\),\},\]. Write a program that determines if the string is a valid parentheses order

# %%
a1 = '{}'             # valid
a2 = '{)}'            # invalid
a3 = '{()()[(){}]}'   # valid
a4 = '({)}'           # invalid
a5 = ''               # valid

# %% [markdown]
# ## 7 Boom
# Write a program that finds all numbers between 1 to 6000 divisible by 7

# %% [markdown]
# #### Solution

# %%
seven_boom = []
for i in range(1, 6001):
    if i % 7 == 0:
        seven_boom.append(i)

# %%
seven_boom
# Out:
# [7,
#  14,
#  21,
#  28,
#  35,
#  42,
#  49,
#  56,
#  63,
#  70,
#  77,
#  84,
#  91,
#  98,
#  105,
#  112,
#  119,
#  126,
#  133,
#  140,
#  147,
#  154,
#  161,
#  168,
#  175,
#  182,
#  189,
#  196,
#  203,
#  210,
#  217,
#  224,
#  231,
#  238,
#  245,
#  252,
#  259,
#  266,
#  273,
#  280,
#  287,
#  294,
#  301,
#  308,
#  315,
#  322,
#  329,
#  336,
#  343,
#  350,
#  357,
#  364,
#  371,
#  378,
#  385,
#  392,
#  399,
#  406,
#  413,
#  420,
#  427,
#  434,
#  441,
#  448,
#  455,
#  462,
#  469,
#  476,
#  483,
#  490,
#  497,
#  504,
#  511,
#  518,
#  525,
#  532,
#  539,
#  546,
#  553,
#  560,
#  567,
#  574,
#  581,
#  588,
#  595,
#  602,
#  609,
#  616,
#  623,
#  630,
#  637,
#  644,
#  651,
#  658,
#  665,
#  672,
#  679,
#  686,
#  693,
#  700,
#  707,
#  714,
#  721,
#  728,
#  735,
#  742,
#  749,
#  756,
#  763,
#  770,
#  777,
#  784,
#  791,
#  798,
#  805,
#  812,
#  819,
#  826,
#  833,
#  840,
#  847,
#  854,
#  861,
#  868,
#  875,
#  882,
#  889,
#  896,
#  903,
#  910,
#  917,
#  924,
#  931,
#  938,
#  945,
#  952,
#  959,
#  966,
#  973,
#  980,
#  987,
#  994,
#  1001,
#  1008,
#  1015,
#  1022,
#  1029,
#  1036,
#  1043,
#  1050,
#  1057,
#  1064,
#  1071,
#  1078,
#  1085,
#  1092,
#  1099,
#  1106,
#  1113,
#  1120,
#  1127,
#  1134,
#  1141,
#  1148,
#  1155,
#  1162,
#  1169,
#  1176,
#  1183,
#  1190,
#  1197,
#  1204,
#  1211,
#  1218,
#  1225,
#  1232,
#  1239,
#  1246,
#  1253,
#  1260,
#  1267,
#  1274,
#  1281,
#  1288,
#  1295,
#  1302,
#  1309,
#  1316,
#  1323,
#  1330,
#  1337,
#  1344,
#  1351,
#  1358,
#  1365,
#  1372,
#  1379,
#  1386,
#  1393,
#  1400,
#  1407,
#  1414,
#  1421,
#  1428,
#  1435,
#  1442,
#  1449,
#  1456,
#  1463,
#  1470,
#  1477,
#  1484,
#  1491,
#  1498,
#  1505,
#  1512,
#  1519,
#  1526,
#  1533,
#  1540,
#  1547,
#  1554,
#  1561,
#  1568,
#  1575,
#  1582,
#  1589,
#  1596,
#  1603,
#  1610,
#  1617,
#  1624,
#  1631,
#  1638,
#  1645,
#  1652,
#  1659,
#  1666,
#  1673,
#  1680,
#  1687,
#  1694,
#  1701,
#  1708,
#  1715,
#  1722,
#  1729,
#  1736,
#  1743,
#  1750,
#  1757,
#  1764,
#  1771,
#  1778,
#  1785,
#  1792,
#  1799,
#  1806,
#  1813,
#  1820,
#  1827,
#  1834,
#  1841,
#  1848,
#  1855,
#  1862,
#  1869,
#  1876,
#  1883,
#  1890,
#  1897,
#  1904,
#  1911,
#  1918,
#  1925,
#  1932,
#  1939,
#  1946,
#  1953,
#  1960,
#  1967,
#  1974,
#  1981,
#  1988,
#  1995,
#  2002,
#  2009,
#  2016,
#  2023,
#  2030,
#  2037,
#  2044,
#  2051,
#  2058,
#  2065,
#  2072,
#  2079,
#  2086,
#  2093,
#  2100,
#  2107,
#  2114,
#  2121,
#  2128,
#  2135,
#  2142,
#  2149,
#  2156,
#  2163,
#  2170,
#  2177,
#  2184,
#  2191,
#  2198,
#  2205,
#  2212,
#  2219,
#  2226,
#  2233,
#  2240,
#  2247,
#  2254,
#  2261,
#  2268,
#  2275,
#  2282,
#  2289,
#  2296,
#  2303,
#  2310,
#  2317,
#  2324,
#  2331,
#  2338,
#  2345,
#  2352,
#  2359,
#  2366,
#  2373,
#  2380,
#  2387,
#  2394,
#  2401,
#  2408,
#  2415,
#  2422,
#  2429,
#  2436,
#  2443,
#  2450,
#  2457,
#  2464,
#  2471,
#  2478,
#  2485,
#  2492,
#  2499,
#  2506,
#  2513,
#  2520,
#  2527,
#  2534,
#  2541,
#  2548,
#  2555,
#  2562,
#  2569,
#  2576,
#  2583,
#  2590,
#  2597,
#  2604,
#  2611,
#  2618,
#  2625,
#  2632,
#  2639,
#  2646,
#  2653,
#  2660,
#  2667,
#  2674,
#  2681,
#  2688,
#  2695,
#  2702,
#  2709,
#  2716,
#  2723,
#  2730,
#  2737,
#  2744,
#  2751,
#  2758,
#  2765,
#  2772,
#  2779,
#  2786,
#  2793,
#  2800,
#  2807,
#  2814,
#  2821,
#  2828,
#  2835,
#  2842,
#  2849,
#  2856,
#  2863,
#  2870,
#  2877,
#  2884,
#  2891,
#  2898,
#  2905,
#  2912,
#  2919,
#  2926,
#  2933,
#  2940,
#  2947,
#  2954,
#  2961,
#  2968,
#  2975,
#  2982,
#  2989,
#  2996,
#  3003,
#  3010,
#  3017,
#  3024,
#  3031,
#  3038,
#  3045,
#  3052,
#  3059,
#  3066,
#  3073,
#  3080,
#  3087,
#  3094,
#  3101,
#  3108,
#  3115,
#  3122,
#  3129,
#  3136,
#  3143,
#  3150,
#  3157,
#  3164,
#  3171,
#  3178,
#  3185,
#  3192,
#  3199,
#  3206,
#  3213,
#  3220,
#  3227,
#  3234,
#  3241,
#  3248,
#  3255,
#  3262,
#  3269,
#  3276,
#  3283,
#  3290,
#  3297,
#  3304,
#  3311,
#  3318,
#  3325,
#  3332,
#  3339,
#  3346,
#  3353,
#  3360,
#  3367,
#  3374,
#  3381,
#  3388,
#  3395,
#  3402,
#  3409,
#  3416,
#  3423,
#  3430,
#  3437,
#  3444,
#  3451,
#  3458,
#  3465,
#  3472,
#  3479,
#  3486,
#  3493,
#  3500,
#  3507,
#  3514,
#  3521,
#  3528,
#  3535,
#  3542,
#  3549,
#  3556,
#  3563,
#  3570,
#  3577,
#  3584,
#  3591,
#  3598,
#  3605,
#  3612,
#  3619,
#  3626,
#  3633,
#  3640,
#  3647,
#  3654,
#  3661,
#  3668,
#  3675,
#  3682,
#  3689,
#  3696,
#  3703,
#  3710,
#  3717,
#  3724,
#  3731,
#  3738,
#  3745,
#  3752,
#  3759,
#  3766,
#  3773,
#  3780,
#  3787,
#  3794,
#  3801,
#  3808,
#  3815,
#  3822,
#  3829,
#  3836,
#  3843,
#  3850,
#  3857,
#  3864,
#  3871,
#  3878,
#  3885,
#  3892,
#  3899,
#  3906,
#  3913,
#  3920,
#  3927,
#  3934,
#  3941,
#  3948,
#  3955,
#  3962,
#  3969,
#  3976,
#  3983,
#  3990,
#  3997,
#  4004,
#  4011,
#  4018,
#  4025,
#  4032,
#  4039,
#  4046,
#  4053,
#  4060,
#  4067,
#  4074,
#  4081,
#  4088,
#  4095,
#  4102,
#  4109,
#  4116,
#  4123,
#  4130,
#  4137,
#  4144,
#  4151,
#  4158,
#  4165,
#  4172,
#  4179,
#  4186,
#  4193,
#  4200,
#  4207,
#  4214,
#  4221,
#  4228,
#  4235,
#  4242,
#  4249,
#  4256,
#  4263,
#  4270,
#  4277,
#  4284,
#  4291,
#  4298,
#  4305,
#  4312,
#  4319,
#  4326,
#  4333,
#  4340,
#  4347,
#  4354,
#  4361,
#  4368,
#  4375,
#  4382,
#  4389,
#  4396,
#  4403,
#  4410,
#  4417,
#  4424,
#  4431,
#  4438,
#  4445,
#  4452,
#  4459,
#  4466,
#  4473,
#  4480,
#  4487,
#  4494,
#  4501,
#  4508,
#  4515,
#  4522,
#  4529,
#  4536,
#  4543,
#  4550,
#  4557,
#  4564,
#  4571,
#  4578,
#  4585,
#  4592,
#  4599,
#  4606,
#  4613,
#  4620,
#  4627,
#  4634,
#  4641,
#  4648,
#  4655,
#  4662,
#  4669,
#  4676,
#  4683,
#  4690,
#  4697,
#  4704,
#  4711,
#  4718,
#  4725,
#  4732,
#  4739,
#  4746,
#  4753,
#  4760,
#  4767,
#  4774,
#  4781,
#  4788,
#  4795,
#  4802,
#  4809,
#  4816,
#  4823,
#  4830,
#  4837,
#  4844,
#  4851,
#  4858,
#  4865,
#  4872,
#  4879,
#  4886,
#  4893,
#  4900,
#  4907,
#  4914,
#  4921,
#  4928,
#  4935,
#  4942,
#  4949,
#  4956,
#  4963,
#  4970,
#  4977,
#  4984,
#  4991,
#  4998,
#  5005,
#  5012,
#  5019,
#  5026,
#  5033,
#  5040,
#  5047,
#  5054,
#  5061,
#  5068,
#  5075,
#  5082,
#  5089,
#  5096,
#  5103,
#  5110,
#  5117,
#  5124,
#  5131,
#  5138,
#  5145,
#  5152,
#  5159,
#  5166,
#  5173,
#  5180,
#  5187,
#  5194,
#  5201,
#  5208,
#  5215,
#  5222,
#  5229,
#  5236,
#  5243,
#  5250,
#  5257,
#  5264,
#  5271,
#  5278,
#  5285,
#  5292,
#  5299,
#  5306,
#  5313,
#  5320,
#  5327,
#  5334,
#  5341,
#  5348,
#  5355,
#  5362,
#  5369,
#  5376,
#  5383,
#  5390,
#  5397,
#  5404,
#  5411,
#  5418,
#  5425,
#  5432,
#  5439,
#  5446,
#  5453,
#  5460,
#  5467,
#  5474,
#  5481,
#  5488,
#  5495,
#  5502,
#  5509,
#  5516,
#  5523,
#  5530,
#  5537,
#  5544,
#  5551,
#  5558,
#  5565,
#  5572,
#  5579,
#  5586,
#  5593,
#  5600,
#  5607,
#  5614,
#  5621,
#  5628,
#  5635,
#  5642,
#  5649,
#  5656,
#  5663,
#  5670,
#  5677,
#  5684,
#  5691,
#  5698,
#  5705,
#  5712,
#  5719,
#  5726,
#  5733,
#  5740,
#  5747,
#  5754,
#  5761,
#  5768,
#  5775,
#  5782,
#  5789,
#  5796,
#  5803,
#  5810,
#  5817,
#  5824,
#  5831,
#  5838,
#  5845,
#  5852,
#  5859,
#  5866,
#  5873,
#  5880,
#  5887,
#  5894,
#  5901,
#  5908,
#  5915,
#  5922,
#  5929,
#  5936,
#  5943,
#  5950,
#  5957,
#  5964,
#  5971,
#  5978,
#  5985,
#  5992,
#  5999]

# %% [markdown]
# ## Verbing (from Google course)
# Given a string, if its length is at least 3,
# add 'ing' to its end.
# Unless it already ends in 'ing', in which case
# add 'ly' instead.
# If the string length is less than 3, leave it unchanged.
# Return the resulting string.

# %%
my_word_1 = 'walk'
my_word_2 = 'swimming'
my_word_3 = 'do'

# %% [markdown]
# #### Solution

# %%
def verbing(word):
    if len(word) >= 3:
        if word[-3:] == 'ing':
            word = word + 'ly'
        else:
            word = word + 'ing'
    return word

# %%
verbing(my_word_3)
# Out:
# 'do'

# %% [markdown]
# ## Python mutability objects
# Write a program that gets a list of elements. For each elements it prints whether it's mutable or immutable

# %%
a = [1, 'my string', [1, 2, 3], (1, 2, 3), {'k1': 1}, True]

# %%
Your program
# Out:
# 1 is immutable
# my string is immutable
# [1, 2, 3] is mutable
# (1, 2, 3) is immutable
# {'k1': 1} is mutable
# True is immutable

# %% [markdown]
# #### Solution

# %%
for obj in a:
    if type(obj) in [int, float, tuple, str, bool]:
        print(obj, 'is immutable')
    else:   # type(obj) in [list, dict]
        print(obj, 'is mutable')
# Out:
# 1 is immutable
# my string is immutable
# [1, 2, 3] is mutable
# (1, 2, 3) is immutable
# {'k1': 1} is mutable
# True is immutable

# %% [markdown]
# ## Valid maill address
# Assuming that a valid email addresses in the "username@companyname.com" format, please write program that verify that a given email address is valid, and prints the user name of a given email address

# %%
m1 = "john@gmail.com"   # valid. username is 'john'
m2 = "@gmailcom"        # invalid.
m3 = "j@gmail"          # invalid. 
m4 = "jo.hn@gmail"      # invalid.

# %% [markdown]
# #### Solution

# %%
valid_chars = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'

def valid_mail(mail):
    # check that @ appears only once in the string
    char_count = 0
    for c in mail:
        if c == '@':
            char_count += 1
        
    if char_count != 1:
        return 'invalid'
    
    # split to username and domain    
    username, domain = mail.split('@')
    
    # check username characters
    for c in username:
        if c not in valid_chars:
            return 'invalid'
    
    # check that . appears only once in domain
    char_count = 0
    for c in domain:
        if c == '.':
            char_count += 1
        
    if char_count != 1:
        return 'invalid'
    
    # split to domain name, and extention
    domain_name, extention = domain.split('.')
    for c in domain_name:
        if c not in valid_chars:
            return 'invalid'
        
    for c in extention:
        if c not in valid_chars:
            return 'invalid'
    
    return 'valid, username is ' + username

# %%
valid_mail(m4)
# Out:
# 'invalid'
